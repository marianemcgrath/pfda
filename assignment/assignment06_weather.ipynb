# %% [markdown]
# ## Knock airport Weather
# Data was taken from this link.
# https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv

# %% [markdown]
# Plot I: The temperature
#
# The mean temperature each day
#
# The mean temperature for each month

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns
import requests

# Confirmation message
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Define file path and name we will be looking at 

FILENAME = "knock_airport.csv"
DATADIR = "data/"
FULLPATH = DATADIR + FILENAME

main_headers = ['DATE', 'TIME', 'TEMP', 'DEWP', 'SLP', 'STP', 'VISIB', 'WDSP', 'MXSPD', 'GUST', 'MAX', 'MIN', 'PRCP', 'SNDP', 'FRSHTT', 'NDR', 'CLDC', 'WNDDIR']

# Read the CSV file into a Data Frame
df = pd.read_csv(FULLPATH, skiprows=22,low_memory=False)

display (df.head())
# Out:
#                 date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0  10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1  31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 2  31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 3  31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 4  31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
# 4  ...     0     0     0      0   2  11  0.0  40000   40     6
#
# [5 rows x 21 columns]

# %%
# setting low_memory to false to stop guessing of column dtypes as this is memory intensive
print(df.shape)
# Out:
# (256434, 21)

# %% [markdown]
# It's vital to consult with the information (metadata) below, as it contains the caption on the parameters measured in the dataset.

# %% [markdown]
#  - date - Date and Time (utc)
#  - rain - Precipitation Amount (mm)
#  - temp - Air Temperature (C)
#  - wetb - Wet Bulb Temperature (C)
#  - dewpt - Dew Point Temperature (C)
#  - rhum - Relative Humidity (%)
#  - vappr - Vapour Pressure (hPa)
#  - msl - Mean Sea Level Pressure (hPa)
#  - wdsp - Mean Wind Speed (knot)
#  - wddir - Predominant Wind Direction (degree)
#  - ww - Synop code for Present Weather
#  - w - Synop code for Past Weather
#  - sun - Sunshine duration (hours)
#  - vis - Visibility (m)
#  - clht - Cloud height (100's of ft) - 999 if none
#  - clamt - Cloud amount
#  - ind - Indicator

# %%
# Check data types before conversion
print("Before conversion:")
print(df['date'].dtype)
print(df['date'].head())

# Convert date column to datetime format with explicit format
df['date'] = pd.to_datetime(df['date'], format='%d-%b-%Y %H:%M', errors='coerce')

print("\nAfter conversion:")
print(df['date'].dtype)
print(df['date'].head())
# Out:
# Before conversion:
# object
# 0    10-apr-1996 14:00
# 1    31-jul-1996 08:00
# 2    31-jul-1996 09:00
# 3    31-jul-1996 10:00
# 4    31-jul-1996 11:00
# Name: date, dtype: object
#
# After conversion:
# datetime64[ns]
# 0   1996-04-10 14:00:00
# 1   1996-07-31 08:00:00
# 2   1996-07-31 09:00:00
# 3   1996-07-31 10:00:00
# 4   1996-07-31 11:00:00
# Name: date, dtype: datetime64[ns]

# %%
# Set date as index and sorting by index to ensure data is sorted properly
if 'date' in df.columns: df.set_index('date', inplace=True)

# sort values
sorted_index = df.index.sort_values()
df = df.loc[sorted_index]

display(df.head())
# Out:
#                      ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# date
# 1996-04-10 14:00:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1996-07-31 08:00:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 1996-07-31 09:00:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 1996-07-31 10:00:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 1996-07-31 11:00:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
#
#                         msl  ind.3 wdsp  ind.4 wddir  ww   w  sun    vis clht  \
# date
# 1996-04-10 14:00:00  1016.7      0    0      0     0  25  81  0.0  35000   32
# 1996-07-31 08:00:00  1011.4      0    0      0     0  25  82  0.0  40000   45
# 1996-07-31 09:00:00  1011.4      0    0      0     0  80  81  0.0   8000   32
# 1996-07-31 10:00:00  1011.2      0    0      0     0  25  82  0.0  28000   35
# 1996-07-31 11:00:00  1011.0      0    0      0     0   2  11  0.0  40000   40
#
#                     clamt
# ...

# %%
# The first plot we are creating must depict the average daily temperature over time
plt.figure(figsize=(18,9))
plt.plot(df.index, df['temp'], label='Daily Temperature', color='purple', alpha=0.5)
plt.title('Average Daily Temperature Over Time at Knock Airport')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid()
plt.show()

# %%
# Grouping by month and year to calculate average temperature
# Select only numeric columns for mean calculation
numeric_columns = df.select_dtypes(include=[np.number]).columns
monthly_data = df[numeric_columns].groupby(df.index.to_period('M')).mean()
yearly_data = df[numeric_columns].groupby(df.index.to_period('Y')).mean()

show_monthly = monthly_data[['temp']]
show_yearly = yearly_data[['temp']]

# Display some of the average temperature data
print("Monthly Average Temperatures (first 10 entries):")
print(show_monthly.head())
print("\nYearly Average Temperatures (first 10 entries):")
print(show_yearly.head(5))
# Out:
# Monthly Average Temperatures (first 10 entries):
#               temp
# date
# 1996-04  11.500000
# 1996-07  12.650000
# 1996-08  12.946909
# 1996-09  12.174306
# 1996-10   9.614113
#
# Yearly Average Temperatures (first 10 entries):
#           temp
# date
# 1996  8.589808
# 1997  9.038664
# 1998  8.615548
# 1999  8.624281
# 2000  8.399158

# %%
# And, but it looks a bit hard to read, so we'll use matplotlib to plot both the average temperatures monthly and yearly over time
plt.figure(figsize=(18,9))
plt.plot(show_monthly.index.to_timestamp(), show_monthly['temp'], label='Monthly Average Temperature', color='blue', alpha=0.7)
plt.plot(show_yearly.index.to_timestamp(), show_yearly['temp'], label='Yearly Average Temperature', color='red', linewidth=2)
plt.title('Average Temperature Over Time at Knock Airport')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend(['Monthly Average Temperature', 'Yearly Average Temperature'])
plt.grid()
plt.show()

# %% [markdown]
# Plot II: The Windspeed
#
# The rolling windspeed (say over 24 hours)
#
# The max windspeed for each day
#
# The monthly mean of the daily max windspeeds

# %%
# Checking for missing values in the Windspeed ('wdsp') column
df['wdsp'].isna().sum()

# Source: https://www.datacamp.com/tutorial/python-nan-missing-values-in-python?utm_cid=19589720821&utm_aid=157156375191&utm_campaign=230119_1-ps-other~dsa~tofu_2-b2c_3-emea_4-prc_5-na_6-na_7-le_8-pdsh-go_9-nb-e_10-na_11-na&utm_loc=1007846-&utm_mtd=-c&utm_kw=&utm_source=google&utm_medium=paid_search&utm_content=ps-other~emea-en~dsa~tofu~tutorial~python&gad_source=1&gad_campaignid=19589720821&gbraid=0AAAAADQ9WsFcrd7oO4ZwUs58vvTLrALU2&gclid=Cj0KCQiAosrJBhD0ARIsAHebCNrJ1WkoCJIBNogVrpcrjpxq1BgQyiacpSj1M8fmrNU5LyIYEEFyVm0aAlSQEALw_wcB
# Out:
# 0

# %%
# But we were assured that there are missing values in this column, so we'll use something different to check how many rows have blank or missing values in the 'wdsp'column
# This will count all unique values in the column including NaN
df['wdsp'].value_counts(dropna=False)

# Source: https://docs.vultr.com/python/third-party/pandas/Series/value_counts (Handling Missing Data)
# Out:
# wdsp
# 6     24144
# 7     23304
# 5     22320
# 8     21234
# 9     19714
# 10    18236
# 4     17060
# 11    16092
# 12    14481
# 13    12281
# 3     10677
# 14    10546
# 15     8573
# 16     6781
# 17     5405
# 2      5137
# 18     4412
# 19     3377
# 20     2601
# 21     1980
# 1      1971
# 22     1574
# 23     1075
# 24      824
# 25      625
# 26      437
# 0       411
# 27      342
# 28      241
# 29      171
# 30      107
# 31       72
# 32       55
#          50
# 33       41
# 34       27
# 35       12
# 39        9
# 38        8
# 36        7
# 37        7
# 40        4
# 42        2
# 49        1
# 50        1
# 48        1
# 43        1
# 44        1
# 46        1
# 47        1
# Name: count, dtype: int64

# %%
# But these contain white space so can convert to np.nan
empty_cells = df['wdsp'].str.startswith(' ').sum()

print(f"Number of rows with whitespace in 'wdsp' column is {empty_cells}")
# Out:
# Number of rows with whitespace in 'wdsp' column is 50

# %%
# We will find rows that have whitespace under Windspeed and replace with None, else use original value
df['wdsp'] = np.where(df['wdsp'].str.startswith(' '), np.nan, df['wdsp'])

# Source: https://www.geeksforgeeks.org/python/replacing-pandas-or-numpy-nan-with-a-none-to-use-with-mysqldb/ (Replacing Pandas or Numpy Nan with a None to use with MysqlDB)

# %%
# Now, when we check again for missing values in the 'wdsp' column
df['wdsp'].isna().sum()
# Out:
# 50

# %%
# Since there are only 50 missing values in the 'wdsp' column (in 256434 rows), we can opt for dropping these rows for the analysis
df = df.dropna(subset=['wdsp'])

# Display the shape of the DataFrame after dropping rows with missing 'wdsp' values
print("DataFrame shape after dropping rows with missing 'wdsp' values:", df.shape)

# Source: https://www.geeksforgeeks.org/machine-learning/handling-missing-values-machine-learning/ (Strategies for Handling Missing Values in Data Analysis)
# Out:
# DataFrame shape after dropping rows with missing 'wdsp' values: (256384, 20)

# %%
# Convert wdsp to numeric first, then calculate the wind speed per quarter
df['wdsp'] = pd.to_numeric(df['wdsp'], errors='coerce')
df['quarter'] = df.index.to_period('Q')
df['year'] = df.index.to_period('Y')

# We will perform average wind speed per quarter and per year
# Initially, it was grouped by month, but the plots looked fairly busy, so we opted for quarter instead
avg_wdsp_per_quarter = df.groupby('quarter')['wdsp'].mean()

# Because the first row (1996 Q2) is 0, we will remove it for better plotting and because it's nearly impossible to have 0 windspeed anyway
avg_wdsp_per_quarter = avg_wdsp_per_quarter[avg_wdsp_per_quarter != 0]

avg_wdsp_per_year = df.groupby('year')['wdsp'].mean()

print("Average Wind Speed per Quarter:")
print(avg_wdsp_per_quarter.head(10))

print("\nAverage Wind Speed per Year:")
print(avg_wdsp_per_year.head(10))
# Out:
# Average Wind Speed per Quarter:
# quarter
# 1996Q3     8.131258
# 1996Q4    10.642329
# 1997Q1    11.317130
# 1997Q2     8.714286
# 1997Q3     8.946558
# 1997Q4     9.654438
# 1998Q1    10.946296
# 1998Q2     8.731685
# 1998Q3     9.822464
# 1998Q4    10.933877
# Freq: Q-DEC, Name: wdsp, dtype: float64
#
# Average Wind Speed per Year:
# year
# 1996     9.620642
# 1997     9.651598
# 1998    10.107763
# 1999    10.230479
# 2000     9.927709
# 2001     9.254224
# 2002    10.010616
# 2003     9.562671
# 2004     9.802937
# 2005     9.590753
# Freq: Y-DEC, Name: wdsp, dtype: float64

# %%
# Let's check for any conversion errors
conversion_errors = df['wdsp'].isna().sum()
conversion_errors
# Out:
# 0

# %%
# Plotting average wind speed per month and Year
plt.figure(figsize=(18,9))
plt.plot(avg_wdsp_per_quarter.index.to_timestamp(), avg_wdsp_per_quarter, label='Quarterly Average Wind Speed', color='blue', alpha=0.7)
plt.plot(avg_wdsp_per_year.index.to_timestamp(), avg_wdsp_per_year, label='Yearly Average Wind Speed', color='red', linewidth=2)
plt.title('Average Wind Speed Over Time at Knock Airport')
plt.xlabel('Year')
plt.ylabel('Average Wind Speed (knots)')
plt.legend()
plt.grid()
plt.show()

# %%
# We want to know the rolling average wind speed over a 24 hour period
# Which is the average wind speed calculated over the previous 24 hours for each point in time
df['rolling_wdsp'] = df['wdsp'].rolling('24h').mean()

# Source: https://www.geeksforgeeks.org/pandas/python-pandas-series-rolling/

# %%
# We'll create a seabborn plot to show the rolling average wind speed over 24 hours
plt.figure(figsize=(18,9))
plt.plot(df.index, df['rolling_wdsp'], color='purple', alpha=0.5)
plt.title('Average Rolling Windspeed Over 24 Hours at Knock Airport')
plt.xlabel('Date')
plt.ylabel('Average Rolling Windspeed (knots)')
plt.legend(['Avg Rolling Windspeed'])
plt.grid()
plt.show()

# %%
# Now, we need to calculate the macximum windspeed for each day
daily_max_wdsp = df['wdsp'].resample('D').max()

# %%
# And let's plot this daily maximum windspeed over time
plt.figure(figsize=(18,9))
plt.plot(daily_max_wdsp.index, daily_max_wdsp, color='blue', alpha=0.7)
plt.title('Daily Maximum Windspeed at Knock Airport')
plt.xlabel('Date')
plt.ylabel('Maximum Wind Speed (knots)')
plt.legend(['Daily Max Windspeed'])
plt.grid()
plt.show()

# %% [markdown]
# # END
