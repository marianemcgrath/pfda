# %% [markdown]
# # **Knock airport Weather**
#
# Author: Mariane McGrath

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import seaborn as sns

# Confirmation message
print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Define file path and name we will be looking at 

FILENAME = "knock_airport.csv"
DATADIR = "data/"
FULLPATH = DATADIR + FILENAME

# Read the CSV file into a Data Frame
# The data file has 22 rows of metadata at the top, so we skip those
df = pd.read_csv(FULLPATH, skiprows=22,low_memory=False)

display (df.head())

# Data was taken from this link:https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv
# Out:
#                 date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0  10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1  31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 2  31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 3  31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 4  31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
#
#    ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# 0  ...     0     0     0      0  25  81  0.0  35000   32     5
# 1  ...     0     0     0      0  25  82  0.0  40000   45     5
# 2  ...     0     0     0      0  80  81  0.0   8000   32     7
# 3  ...     0     0     0      0  25  82  0.0  28000   35     6
# 4  ...     0     0     0      0   2  11  0.0  40000   40     6
#
# [5 rows x 21 columns]

# %%
# Check the shape of the Data Frame
# This will give us the number of rows and columns in the dataset
print(df.shape)
# Out:
# (256434, 21)

# %% [markdown]
# **To better understand the data, it's vital to consult with the information (metadata) below, as it contains the columns and the parameters measured in the dataset.**

# %% [markdown]
#  - date - Date and Time (utc)
#  - rain - Precipitation Amount (mm)
#  - temp - Air Temperature (C)
#  - wetb - Wet Bulb Temperature (C)
#  - dewpt - Dew Point Temperature (C)
#  - rhum - Relative Humidity (%)
#  - vappr - Vapour Pressure (hPa)
#  - msl - Mean Sea Level Pressure (hPa)
#  - wdsp - Mean Wind Speed (knot)
#  - wddir - Predominant Wind Direction (degree)
#  - ww - Synop code for Present Weather
#  - w - Synop code for Past Weather
#  - sun - Sunshine duration (hours)
#  - vis - Visibility (m)
#  - clht - Cloud height (100's of ft) - 999 if none
#  - clamt - Cloud amount
#  - ind - Indicator

# %%
# Check data types before conversion
print("Before conversion:")
print(df['date'].dtype)
print(df['date'].head(3))

# Convert date column to datetime format with explicit format
df['date'] = pd.to_datetime(df['date'], format='%d-%b-%Y %H:%M', errors='coerce')

print("\nAfter conversion:")
print(df['date'].dtype)
print(df['date'].head(3))

# Source: https://stackoverflow.com/questions/38333954/converting-object-to-datetime-format-in-python
# Source: https://docs.python.org/3/library/datetime.html
# Out:
# Before conversion:
# object
# 0    10-apr-1996 14:00
# 1    31-jul-1996 08:00
# 2    31-jul-1996 09:00
# Name: date, dtype: object
#
# After conversion:
# datetime64[ns]
# 0   1996-04-10 14:00:00
# 1   1996-07-31 08:00:00
# 2   1996-07-31 09:00:00
# Name: date, dtype: datetime64[ns]

# %%
# Set date as index and sorting by index to ensure data is sorted properly
if 'date' in df.columns: df.set_index('date', inplace=True)

# Sort the DataFrame by the datetime index
sorted_index = df.index.sort_values()
df = df.loc[sorted_index]

display(df.head())

# Source: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
# Source: https://www.geeksforgeeks.org/pandas/python-pandas-dataframe-set_index/
# Source: https://pydata-sphinx-theme.readthedocs.io/en/v0.11.0/examples/example_pandas.html
# Source: https://www.datacamp.com/tutorial/loc-vs-iloc?utm_cid=19589720821&utm_aid=157156374671&utm_campaign=230119_1-ps-other~dsa~tofu_2-b2c_3-emea_4-prc_5-na_6-na_7-le_8-pdsh-go_9-nb-e_10-na_11-na&utm_loc=1007846-&utm_mtd=-c&utm_kw=&utm_source=google&utm_medium=paid_search&utm_content=ps-other~emea-en~dsa~tofu~tutorial~data-science&gad_source=1&gad_campaignid=19589720821&gbraid=0AAAAADQ9WsFcrd7oO4ZwUs58vvTLrALU2&gclid=CjwKCAiAxc_JBhA2EiwAFVs7XFz__sWydDIAstsydkdc7Wniu7kohyWBKmWIqpcN3gl5yfM-Mm8RlhoCXFIQAvD_BwE
# Out:
#                      ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# date
# 1996-04-10 14:00:00    0  0.0      0  11.5      0   8.1    3.9    0.0     0
# 1996-07-31 08:00:00    0  0.0      0  11.5      0  11.1   10.7    0.0     0
# 1996-07-31 09:00:00    0  0.0      0  11.6      0  10.7    9.8    0.0     0
# 1996-07-31 10:00:00    0  0.0      0  12.9      0  11.3    9.8    0.0     0
# 1996-07-31 11:00:00    0  0.0      0  14.5      0  10.8    7.0    0.0     0
#
#                         msl  ind.3 wdsp  ind.4 wddir  ww   w  sun    vis clht  \
# date
# 1996-04-10 14:00:00  1016.7      0    0      0     0  25  81  0.0  35000   32
# 1996-07-31 08:00:00  1011.4      0    0      0     0  25  82  0.0  40000   45
# 1996-07-31 09:00:00  1011.4      0    0      0     0  80  81  0.0   8000   32
# 1996-07-31 10:00:00  1011.2      0    0      0     0  25  82  0.0  28000   35
# 1996-07-31 11:00:00  1011.0      0    0      0     0   2  11  0.0  40000   40
#
#                     clamt
# ...

# %% [markdown]
# ## **Part I: The temperature**

# %% [markdown]
# ### **Plot of the temperature**

# %%
# Now, we plot the daily temperature at knock airport
fig, ax = plt.subplots(figsize=(14, 8))
sns.lineplot(data=df,x='date',y='temp', ax=ax, color='blue', alpha=0.8)
ax.set_ylabel('Temperature (°C)')
ax.set_xlabel('Time')
ax.legend(['Daily Temperature'], loc='upper left')
ax.set_title('Temperature (°C) over Time')
ax.grid(True, which='both', linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# Source: https://seaborn.pydata.org/generated/seaborn.lineplot.html (Seaborn lineplot)

# %% [markdown]
# ### **The mean temperature each day**

# %%
# To get the mean daily temperature, we resample the data by day and calculate the mean for each day
mean_daily_temp = df['temp'].resample('D').mean() # resampling per day 

# Source: https://www.geeksforgeeks.org/python/python-pandas-dataframe-resample/
# Source: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.resample.html

# %%
# Plotting the average daily temperature over time
plt.figure(figsize=(14, 8))
plt.plot(mean_daily_temp.index, mean_daily_temp, label='Average Daily Temperature', color='purple', alpha=0.8)
plt.title('Average Daily Temperature Over Time at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# Source: https://pandas.pydata.org/pandas-docs/version/0.13/visualization.html

# %% [markdown]
# ### **The mean temperature for each month**
# *   **And I added yearly as well, for comparison**

# %%
# Grouping by month and year to calculate average temperature
# Select only numeric columns for mean calculation
numeric_columns = df.select_dtypes(include=[np.number]).columns

# Group by month and year, calculating the mean for each period
monthly_data = df[numeric_columns].groupby(df.index.to_period('M')).mean()
yearly_data = df[numeric_columns].groupby(df.index.to_period('Y')).mean()

# Select only the temperature column for display
show_monthly = monthly_data[['temp']]
show_yearly = yearly_data[['temp']]

# Display some of the average temperature data
print("Monthly Average Temperatures (first 5 entries):")
print(show_monthly.head(5))
print("\nYearly Average Temperatures (first 5 entries):")
print(show_yearly.head(5))

# Source: https://www.geeksforgeeks.org/python/how-to-group-pandas-dataframe-by-date-and-time/
# Out:
# Monthly Average Temperatures (first 5 entries):
#               temp
# date
# 1996-04  11.500000
# 1996-07  12.650000
# 1996-08  12.946909
# 1996-09  12.174306
# 1996-10   9.614113
#
# Yearly Average Temperatures (first 5 entries):
#           temp
# date
# 1996  8.589808
# 1997  9.038664
# 1998  8.615548
# 1999  8.624281
# 2000  8.399158

# %%
# And, we'll plot both the average temperatures monthly and yearly over time
plt.figure(figsize=(14, 8))
plt.plot(show_monthly.index.to_timestamp(), show_monthly['temp'], label='Monthly Average Temperature', color='blue', alpha=0.8)
plt.plot(show_yearly.index.to_timestamp(), show_yearly['temp'], label='Yearly Average Temperature', color='red', linewidth=2)
plt.title('Average Temperature Over Time at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.legend(['Monthly Average Temperature', 'Yearly Average Temperature'])
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Part II: The Windspeed**

# %%
# Checking for missing values in the Windspeed ('wdsp') column
df['wdsp'].isna().sum()

# Source: https://www.datacamp.com/tutorial/python-nan-missing-values-in-python (Handling missing values)
# Out:
# 0

# %% [markdown]
# According to the code above, there are no empty cells under the windspeed (wdsp) clolumn. However, the task brief stated that there are missing values in this column, so we'll use something different to check how many rows have blank or missing values in the 'wdsp'column.

# %%
# This will count all unique values in the column including NaN
df['wdsp'].value_counts(dropna=False)

# Source: https://docs.vultr.com/python/third-party/pandas/Series/value_counts (Handling Missing Data)
# Out:
# wdsp
# 6     24144
# 7     23304
# 5     22320
# 8     21234
# 9     19714
# 10    18236
# 4     17060
# 11    16092
# 12    14481
# 13    12281
# 3     10677
# 14    10546
# 15     8573
# 16     6781
# 17     5405
# 2      5137
# 18     4412
# 19     3377
# 20     2601
# 21     1980
# 1      1971
# 22     1574
# 23     1075
# 24      824
# 25      625
# 26      437
# 0       411
# 27      342
# 28      241
# 29      171
# 30      107
# 31       72
# 32       55
#          50
# 33       41
# 34       27
# 35       12
# 39        9
# 38        8
# 36        7
# 37        7
# 40        4
# 42        2
# 49        1
# 50        1
# 48        1
# 43        1
# 44        1
# 46        1
# 47        1
# Name: count, dtype: int64

# %%
# But, there is white space so can convert to np.nan
empty_cells = df['wdsp'].str.startswith(' ').sum()

print(f"Number of rows with whitespace in 'wdsp' column is {empty_cells}")

# We will find rows that have whitespace under Windspeed and replace with None, else use original value
df['wdsp'] = np.where(df['wdsp'].str.startswith(' '), np.nan, df['wdsp'])

# Source: https://www.geeksforgeeks.org/python/replacing-pandas-or-numpy-nan-with-a-none-to-use-with-mysqldb/ (Replacing Pandas or Numpy Nan with a None to use with MysqlDB)
# Out:
# Number of rows with whitespace in 'wdsp' column is 50

# %%
# Now, when we check again for missing values in the 'wdsp' column, with the fist method
df['wdsp'].isna().sum()
# Out:
# 50

# %%
# Since there are only 50 missing values in the 'wdsp' column (in more than 250 thousand rows), we will opt for 
# dropping these rows for the analysis
df = df.dropna(subset=['wdsp'])

# Display the shape of the DataFrame after dropping rows with missing 'wdsp' values
print("DataFrame shape after dropping rows with missing 'wdsp' values:", df.shape)

# Source: https://www.geeksforgeeks.org/machine-learning/handling-missing-values-machine-learning/ (Strategies for Handling Missing Values in Data Analysis)
# Out:
# DataFrame shape after dropping rows with missing 'wdsp' values: (256384, 20)

# %%
# Convert wdsp to numeric first, then calculate the wind speed per quarter (as monthly would look too busy in this case)
df['wdsp'] = pd.to_numeric(df['wdsp'], errors='coerce')
df['quarter'] = df.index.to_period('Q')
df['year'] = df.index.to_period('Y')

# We will perform average wind speed per quarter and per year
# Initially, it was grouped by month, but the plots looked fairly busy, so we opted for quarter instead
avg_wdsp_per_quarter = df.groupby('quarter')['wdsp'].mean()

# Because the first row (1996 Q2) is 0, we will remove it for better plotting and because it's nearly impossible to have 0 windspeed anyway
avg_wdsp_per_qtr = avg_wdsp_per_quarter[avg_wdsp_per_quarter != 0]

print("Average Wind Speed per Quarter:")
print(avg_wdsp_per_qtr.head(10))


# Source: https://www.geeksforgeeks.org/python/python-pandas-to_numeric-method/ (Using pd.to_numeric() method in Pandas)
# Source: https://stackoverflow.com/questions/23840797/convert-a-column-of-timestamps-into-periods-in-pandas (Convert a column of timestamps into Periods)
# Source: https://stackoverflow.com/questions/29314424/pandas-using-groupby-to-get-mean-for-each-data-category (Pandas: Using groupby to get mean different categories)
# Source: https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.to_period.html (Convert DatetimeIndex to PeriodIndex)
# Out:
# Average Wind Speed per Quarter:
# quarter
# 1996Q3     8.131258
# 1996Q4    10.642329
# 1997Q1    11.317130
# 1997Q2     8.714286
# 1997Q3     8.946558
# 1997Q4     9.654438
# 1998Q1    10.946296
# 1998Q2     8.731685
# 1998Q3     9.822464
# 1998Q4    10.933877
# Freq: Q-DEC, Name: wdsp, dtype: float64

# %% [markdown]
# ### **Plot of the windspeed**

# %%
# Let's plot the average wind speed per quarter over time
plt.figure(figsize=(14, 8))
plt.plot(avg_wdsp_per_qtr.index.to_timestamp(), avg_wdsp_per_qtr, label='Average Wind Speed per Quarter', color='blue', alpha=0.8, linewidth=2)
plt.title('Quarterly Average Wind Speed in knots at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Average Wind Speed (knots)')
plt.legend()
plt.grid( True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# %%
# Let's check for any conversion errors after the latest changes
conversion_errors = df['wdsp'].isna().sum()
conversion_errors

if conversion_errors > 0:
        print(f"Number of conversion errors in 'wdsp' column is {conversion_errors} - please check data!")
else:
    print(f"Number of conversion errors in 'wdsp' column: {conversion_errors}", "- all good!")
# Out:
# Number of conversion errors in 'wdsp' column: 0 - all good!

# %%
# We want to know the rolling average wind speed over a 24 hour period
# Which is the average wind speed calculated over the previous 24 hours for each point in time
df['rolling_wdsp'] = df['wdsp'].rolling('24h').mean()

# Source: https://www.geeksforgeeks.org/pandas/python-pandas-series-rolling/ (Rolling function in Pandas)
# Source: https://stackoverflow.com/questions/69671067/pandas-rolling-time-window-by-days-instead-of-individual-rows (Rolling function with time window)

# %% [markdown]
# ### **Plot of the rolling windspeed (over 24 hours)**

# %%
# We'll create a seabborn plot to show the rolling average wind speed over 24 hours
plt.figure(figsize=(14, 8))
plt.plot(df.index, df['rolling_wdsp'], color='purple', alpha=0.8)
plt.title('Average Rolling Windspeed Over 24 Hours at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Average Rolling Windspeed (knots)')
plt.legend(['Avg Rolling Windspeed'])
plt.grid( True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Plot of the daily maximum windspeed**

# %%
# Now, we need to calculate the maximum windspeed for each day
max_day_wdsp = df['wdsp'].resample('D').max() 

# Source: https://www.geeksforgeeks.org/python/python-pandas-dataframe-resample/ (Resampling in Pandas)
# Source: https://medium.com/@whyamit101/understanding-pandas-resample-with-simple-examples-6c58cc252fbd (Understanding Resample)

# %%
# And let's plot this daily maximum windspeed over time
plt.figure(figsize=(14, 8))
plt.plot(max_day_wdsp.index, max_day_wdsp, color='blue', alpha=0.8)
plt.title('Daily Maximum Windspeed at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Maximum Wind Speed (knots)')
plt.legend(['Daily Max Windspeed'])
plt.grid(alpha=True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Plot of the monthly average of the daily maximum windspeeds**

# %%
# We'll calculate the monthly mean of the daily maximum wind speed
max_day_wdsp = df['wdsp'].resample('D').max() # Resampling per day, to get daily max
month_mean_wdsp = max_day_wdsp.resample('ME').mean() # Resampling per month of daily max

# But, we need to remove the months with incomplete data (NaN values) or data that is equal to 0 at the start
# as it can skew the result, as seen previously
month_mean_wdsp = month_mean_wdsp.dropna()  # Removing NaN values
month_mean_wdsp = month_mean_wdsp[month_mean_wdsp != 0]  # Removing zero values

# Sources: https://docs.vultr.com/python/third-party/pandas/DataFrame/resample (Pandas Resample)

# %%
# Finally, we'll plot the monthly average of daily maximum wind speed
plt.figure(figsize=(14, 8))
plt.plot(month_mean_wdsp.index, month_mean_wdsp, label='Monthly Mean of Daily Max Wind Speed', color='purple', alpha=0.8)
plt.title('Monthly Mean of Daily Max Wind Speed (Knots) at Knock Airport')
plt.xlabel('Time')
plt.ylabel('Average Wind Speed (knots)')
plt.legend()
plt.grid(alpha=True, linestyle='--', linewidth=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# End
